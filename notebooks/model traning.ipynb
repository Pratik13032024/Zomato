# %%
import pandas as pd
df=pd.read_csv('data/finalTrain.csv')
df
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 0      0xcdcd      DEHRES17DEL01                 36.0
# 1      0xd987      KOCRES16DEL01                 21.0
# 2      0x2784     PUNERES13DEL03                 23.0
# 3      0xc8b6     LUDHRES15DEL02                 34.0
# 4      0xdb64      KNPRES14DEL02                 24.0
# ...       ...                ...                  ...
# 45579  0x7c09      JAPRES04DEL01                 30.0
# 45580  0xd641      AGRRES16DEL01                 21.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
# 45582  0x5eee    COIMBRES11DEL01                 20.0
# 45583  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                          4.2            30.327968             78.046106
# 1                          4.7            10.003064             76.307589
# 2                          4.7            18.562450             73.916619
# ...

# %%
df.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
df.dropna(axis=0,how='any',inplace=True)
df.isnull().sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weather_conditions             0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken (min)               0
# dtype: int64

# %%
df.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
list(df.columns)
# Out:
# ['ID',
#  'Delivery_person_ID',
#  'Delivery_person_Age',
#  'Delivery_person_Ratings',
#  'Restaurant_latitude',
#  'Restaurant_longitude',
#  'Delivery_location_latitude',
#  'Delivery_location_longitude',
#  'Order_Date',
#  'Time_Orderd',
#  'Time_Order_picked',
#  'Weather_conditions',
#  'Road_traffic_density',
#  'Vehicle_condition',
#  'Type_of_order',
#  'Type_of_vehicle',
#  'multiple_deliveries',
#  'Festival',
#  'City',
#  'Time_taken (min)']

# %%
df.drop(columns=['ID',
 'Delivery_person_ID','Order_Date','Type_of_order','Time_Orderd',
 'Time_Order_picked','Festival',
 'Type_of_vehicle',],inplace=True)

# %%
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude Weather_conditions Road_traffic_density  \
# 0                    78.116106                Fog                  Jam
# 1                    76.347589             Stormy                 High
# ...

# %%
df.dtypes
# Out:
# Delivery_person_Age            float64
# Delivery_person_Ratings        float64
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Weather_conditions              object
# Road_traffic_density            object
# Vehicle_condition                int64
# multiple_deliveries            float64
# City                            object
# Time_taken (min)                 int64
# dtype: object

# %%
cat_columns = X.select_dtypes(include='object').columns
numerical_columns = X.select_dtypes(exclude='object').columns
print(cat_columns)
print(numerical_columns)
# Out:
# Index(['Weather_conditions', 'Road_traffic_density', 'City'], dtype='object')
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Vehicle_condition',
#        'multiple_deliveries'],
#       dtype='object')

# %%
df[cat_columns].describe()
# Out:
#        Weather_conditions Road_traffic_density           City
# count               41359                41359          41359
# unique                  6                    4              3
# top                   Fog                  Low  Metropolitian
# freq                 7115                13980          31816

# %%
X=df.drop('Time_taken (min)',axis=1)
y=df['Time_taken (min)']

# %%
y
# Out:
# 0        46
# 1        23
# 2        21
# 3        20
# 4        41
#          ..
# 45579    32
# 45580    36
# 45581    16
# 45582    26
# 45583    36
# Name: Time_taken (min), Length: 41359, dtype: int64

# %%
df['Weather_conditions'].unique()
# Out:
# array(['Fog', 'Stormy', 'Sandstorms', 'Windy', 'Cloudy', 'Sunny'],
#       dtype=object)

# %%
df['Road_traffic_density'].unique()
# Out:
# array(['Jam', 'High', 'Medium', 'Low'], dtype=object)

# %%
df['City'].unique()
# Out:
# array(['Metropolitian', 'Urban', 'Semi-Urban'], dtype=object)

# %%
Weather_conditions_cat=['Fog', 'Stormy', 'Sandstorms', 'Windy', 'Cloudy', 'Sunny']
Road_traffic_cat=['Jam', 'High', 'Medium', 'Low']
City_cat=['Metropolitian', 'Urban', 'Semi-Urban']

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
##Numrical pipeline
num_pipeline=Pipeline(
    steps=[
        ('imputer',SimpleImputer(strategy='median')),
        ('scaler',StandardScaler())

]
)

#Cat pipeline

cat_pipeline=Pipeline(
    steps=[
        ('imputer',SimpleImputer(strategy='most_frequent')),
        ('ordinalencoder',OrdinalEncoder(categories=[Weather_conditions_cat,Road_traffic_cat,City_cat])),
        ('scaler',StandardScaler())

    ]
)

preprocessor=ColumnTransformer([
    ('num_pipeline',num_pipeline,numerical_columns),
    ('cat_pipeline',cat_pipeline,cat_columns)
])

# %%
print(type(preprocessor))
# Out:
# <class 'sklearn.compose._column_transformer.ColumnTransformer'>

# %%
df.dtypes
# Out:
# Delivery_person_Age            float64
# Delivery_person_Ratings        float64
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Weather_conditions              object
# Road_traffic_density            object
# Vehicle_condition                int64
# multiple_deliveries            float64
# City                            object
# Time_taken (min)                 int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=30)

# %%
X_train=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())

# %%
X_test=pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out())

# %%
#model Traning

from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
#defining function to evaluare the model
def evaluate_model(y_true,_y_pred):
    mae=mean_absolute_error(y_true,_y_pred)
    rmse=np.sqrt(mean_squared_error(y_true,_y_pred))
    r2_square=r2_score(y_true,_y_pred)
    return mae,rmse,r2_square

#Add all models to the dict
models = {
    'LinearRegression': LinearRegression(),
    'Lasso': Lasso(),
    'Ridge': Ridge(),
    'ElasticNet': ElasticNet(),
    'DecisionTree': DecisionTreeRegressor(),
    'RandomForest': RandomForestRegressor(),
    'GradientBoosting': GradientBoostingRegressor(),
    'AdaBoost': AdaBoostRegressor(),
    'SVR': SVR(),
    'KNeighbors': KNeighborsRegressor(),
    'GaussianNB': GaussianNB()  # For classification
}

trained_model_list = []
model_list = []
r2_list = []

# Iterate through the models and train each
for name, model in models.items():
    # Train the model
    model.fit(X_train, y_train)

    # Make predictions
    y_pred = model.predict(X_test)

    # Evaluate the model
    mae, rmse, r2_square = evaluate_model(y_test, y_pred)

    # Print the results
    print(name)
    model_list.append(name)
    print('Model Training Performance')
    print("RMSE:", rmse)
    print("MAE:", mae)
    print("R2 score:", r2_square * 100)

    r2_list.append(r2_square)
    
    print('=' * 35)
    print('\n')
# Out:
# LinearRegression
# Model Training Performance
# RMSE: 6.506238342351766
# MAE: 5.1559768820609735
# R2 score: 51.51844472285837
# ...
#
#
# Lasso
# Model Training Performance
# RMSE: 7.128826767950735
# MAE: 5.672508486107661
# R2 score: 41.796013833014555
# ...
#
#
# Ridge
# Model Training Performance
# RMSE: 6.7222175965416255
# MAE: 5.314798321022063
# R2 score: 48.2462601082085
# ...
#
#
# ElasticNet
# Model Training Performance
# RMSE: 7.222434014550675
# MAE: 5.760847223886571
# R2 score: 40.25744782498286
# ...
#
#
# DecisionTree
# Model Training Performance
# RMSE: 6.474051105851997
# MAE: 4.816959488502041
# R2 score: 51.996947732859056
# ...
#
#
# RandomForest
# Model Training Performance
# RMSE: 4.81428083747618
# MAE: 3.7448543342492813
# R2 score: 73.45520058906745
# ...
#
#
# GradientBoosting
# Model Training Performance
# RMSE: 5.198624095811001
# MAE: 4.113368954960563
# R2 score: 69.04766359192355
# ...
#
#
# AdaBoost
# Model Training Performance
# RMSE: 6.4433639142669215
# MAE: 5.302562933798682
# ...
